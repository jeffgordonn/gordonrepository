# %% [markdown]
# # Data Science Project
# Scraping the websites for information
# ### Step 1: WebScraping

# %%
# !pip install pandas==1.3.3
# !pip install requests==2.26.0
# !mamba install bs4==4.10.0 -y
# !mamba install html5lib==1.1 -y 
# !pip install lxml==4.6.4
# !pip install plotly==5.3.1
# Out:
# ...
#   Using cached pandas-1.3.3.tar.gz (4.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [239 lines of output]
#   Ignoring numpy: markers 'python_version == "3.7" and (platform_machine != "arm64" or platform_system != "Darwin") and platform_machine != "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.8" and (platform_machine != "arm64" or platform_system != "Darwin") and platform_machine != "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_machine == "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.8" and platform_machine == "aarch64"' don't match your environment
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
### example_url = "https://tax1.co.monmouth.nj.us/cgi-bin/m4.cgi?district=1102&l02=110200003____00002_________M"
url = input("What is the URL? ")
# Out:
# What is the URL? https://tax1.co.monmouth.nj.us/cgi-bin/m4.cgi?district=1101&l02=110100003____00004_________M

# %%
assm_df = pd.DataFrame(columns=['block','lot','prop_loc','owner','sq_ft','district','street', 'year_built','qual','class_','city_state','style','prior_block','acct_num','addl_lots','epl_code','prior_lot','mtg_act','land_desc','statute','prior_qual','bank_code','bldg_desc','initial','updated','tax_codes','class4cd','desc','zone','map_page','acreage','taxes','sale_date','book', 'price','NU'])

# %%
## Trying to webscrape uisng pandas .read_html()
assm_data = pd.read_html(url, flavor='bs4')

# %%
assm_data
# Out:
# [                         0                       1                       2  \
#  0                   Block:                       3               Prop Loc:
#  1                     Lot:                       4               District:
#  2                    Qual:                     NaN                  Class:
#  3   Additional Information  Additional Information  Additional Information
#  4             Prior Block:                     NaN               Acct Num:
#  5               Prior Lot:                     NaN               Mtg Acct:
#  6              Prior Qual:                     NaN              Bank Code:
#  7                 Updated:                01/15/20              Tax Codes:
#  8                    Zone:                      RO               Map Page:
#  9         Sale Information        Sale Information        Sale Information
#  10              Sale Date:                05/02/90                   Book:
#
#                             3                       4  \
# ...

# %%
## use indexes to lock in the data
block = assm_data[0][1][0]
lot = assm_data[0][1][1]
qual = assm_data[0][1][2]
prior_block = assm_data[0][1][4]
prior_lot = assm_data[0][1][5]
prior_qual = assm_data[0][1][6]
updated = assm_data[0][1][7]
zone = assm_data[0][1][8]
sale_date = assm_data[0][1][10]
prop_loc = assm_data[0][3][0]
district = assm_data[0][3][1]
class_ = assm_data[0][3][2]
acct_num = assm_data[0][3][4]
mtg_acct = assm_data[0][3][5]
bank_code = assm_data[0][3][6]
tax_codes = assm_data[0][3][7]
map_page = assm_data[0][3][8]
book = assm_data[0][3][10]
owner = assm_data[0][5][0]
street = assm_data[0][5][1]
city_state = assm_data[0][5][2]
addl_lots = assm_data[0][5][4]
land_desc = assm_data[0][5][5]
bldg_desc = assm_data[0][5][6]
class4cd = assm_data[0][5][7]
acreage = assm_data[0][5][8]
price = assm_data[0][5][10][0]
sq_ft = assm_data[0][7][0]
year_built = assm_data[0][7][1]
style = assm_data[0][7][2]
epl_code = assm_data[0][7][4]
statute = assm_data[0][7][5]
initial = assm_data[0][7][6]
desc = assm_data[0][7][7]
taxes = assm_data[0][7][8]
NU = assm_data[0][5][10][-1]

## add them to the pandas dataframe
## this does not have the same order so keep in mind if manually checking
    
assm_df = assm_df.append({'block': block, 'lot': lot, 'prop_loc': prop_loc,'owner': owner,'sq_ft': sq_ft, 'district': district,'street': street, 'year_built': year_built, 'qual': qual,'class_': class_,'city_state': city_state,'style': style, 'prior_block': prior_block,'acct_num': acct_num, 'addl_lots': addl_lots,'epl_code': epl_code, 'prior_lot': prior_lot,'mtg_acct': mtg_acct,'land_desc': land_desc,'statute': statute, 'prior_qual': prior_qual,'bank_code': bank_code,'bldg_desc': bldg_desc,'initial': initial, 'updated': updated,'tax_codes': tax_codes,'class4cd': class4cd,'desc': desc, 'zone': zone,'map_page': map_page,'acreage': acreage,'taxes': taxes, 'sale_date': sale_date,'book': book, 'price': price,'NU': NU},ignore_index=True)
# Out:
# C:\Users\jeffg\AppData\Local\Temp\ipykernel_2528\298135333.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assm_df = assm_df.append({'block': block, 'lot': lot, 'prop_loc': prop_loc,'owner': owner,'sq_ft': sq_ft, 'district': district,'street': street, 'year_built': year_built, 'qual': qual,'class_': class_,'city_state': city_state,'style': style, 'prior_block': prior_block,'acct_num': acct_num, 'addl_lots': addl_lots,'epl_code': epl_code, 'prior_lot': prior_lot,'mtg_acct': mtg_acct,'land_desc': land_desc,'statute': statute, 'prior_qual': prior_qual,'bank_code': bank_code,'bldg_desc': bldg_desc,'initial': initial, 'updated': updated,'tax_codes': tax_codes,'class4cd': class4cd,'desc': desc, 'zone': zone,'map_page': map_page,'acreage': acreage,'taxes': taxes, 'sale_date': sale_date,'book': book, 'price': price,'NU': NU},ignore_index=True)

# %%
assm_df.head()
# Out:
#   block lot                  prop_loc                         owner sq_ft  \
# 0     3   4  353 PRINCETON-HIGHTSTOWN  MARDER, HENRY S. & EILEEN R.  1331
#
#             district                    street year_built qual class_  ...  \
# 0  1101 EAST WINDSOR  353 PRINCETON-HIGHTSTOWN       1960  NaN     4A  ...
#
#   desc zone map_page acreage            taxes sale_date            book price  \
# 0  NaN   RO        2     1.3  17026.60 / 0.00  05/02/90  2527 Page: 668     2
#
#   NU mtg_acct
# 0  0      NaN
#
# [1 rows x 37 columns]

# %%
# !pip install openpyxl

# %%
with pd.ExcelWriter(r'C:\Users\jeffg\downloads\test.xlsx', mode='a', engine='openpyxl', if_sheet_exists = 'replace') as writer:
    assm_df.to_excel(writer,sheet_name='test_2')
    writer.save()
# Out:
# C:\Users\jeffg\AppData\Local\Temp\ipykernel_2528\915088360.py:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %% [markdown]
# ## Build a URL code that can be adjusted and can take block and lots as input

# %%
import re

# %%
county_name = input("County: ")
town_city_name = input("Township/Municipality/City: ")
block = input("Block: ")
lot = input("Lot: ")

county_name = str(county_name.lower())
town_city_name = str(town_city_name.lower())

path = r'C:\\Users\\jeffg\\downloads\\227463163_1.xlsx'
sheet = 'county data'
sheet1 = 'towncity data'

# retrieve the number associated with each county
# NOTE: create an XLSX or SQL table with 1 distinct value and 1 distinct county, otherwise the loc function will mess up
county_data = pd.read_excel(path, sheet, usecols = ['county_number','county'])
county_data['county'] = county_data['county'].str.lower()
county_data = county_data.set_index('county')

county = county_data.loc[county_name,'county_number']

# retrieve the number accociated with each town/city
# AGAIN: setting the index requires distinguishable and distinct values- in excel, I concatenated the town and the county to make it a distinct value
towncity_data = pd.read_excel(path, sheet1, usecols = ['town_city_index','county_number','town_city_number','town_city'])
towncity_data['town_city_index'] = towncity_data['town_city_index'].str.lower()
towncity_data['town_city'] = towncity_data['town_city'].str.lower()
towncity_data = towncity_data.set_index('town_city_index')

town_city = towncity_data.loc[county_name+'-'+town_city_name, 'town_city_number']
town_city

## build an if then function to adjust for different lengths of the block and lots, as well build regex expection handling for the special characters

if block < 10 and lot < 10:
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0000{block}____0000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif block < 10 and (10 <= lot < 100):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0000{block}____000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif block < 10 and (100 <= lot < 1000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0000{block}____00{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif block < 10 and (1000 <= lot < 10000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0000{block}____0{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif block < 10 and (10000 <= lot < 100000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0000{block}____{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10 <= block < 100) and lot < 10:
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}000{block}____0000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10 <= block < 100) and (10 <= lot < 100):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}000{block}____000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10 <= block < 100) and (100 <= lot < 1000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}000{block}____00{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10 <= block < 100) and (1000 <= lot < 10000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}000{block}____0{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10 <= block < 100) and (10000 <= lot < 100000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}000{block}____{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (100 <= block < 1000) and lot < 10:
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}00{block}____0000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (100 <= block < 1000) and (10 <= lot < 100):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}00{block}____000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (100 <= block < 1000) and (100 <= lot < 1000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}00{block}____00{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (100 <= block < 1000) and (1000 <= lot < 10000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}00{block}____0{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (100 <= block < 1000) and (10000 <= lot < 100000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}00{block}____{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (1000 <= block < 10000) and lot < 10:
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0{block}____0000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (1000 <= block < 10000) and (10 <= lot < 100):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0{block}____000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (1000 <= block < 10000) and (100 <= lot < 1000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0{block}____00{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (1000 <= block < 10000) and (1000 <= lot < 10000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0{block}____0{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (1000 <= block < 10000) and (10000 <= lot < 100000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0{block}____{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10000 <= block < 100000) and lot < 10:
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}{block}____0000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10000 <= block < 100000) and (10 <= lot < 100):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}{block}____000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10000 <= block < 100000) and (100 <= lot < 1000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}{block}____00{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10000 <= block < 100000) and (1000 <= lot < 10000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}{block}____0{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10000 <= block < 100000) and (10000 <= lot < 100000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}{block}____{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif block < 10 and lot < 10:
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0000{block}____0000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif block < 10 and (10 <= lot < 100):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0000{block}____000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif block < 10 and (100 <= lot < 1000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0000{block}____00{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif block < 10 and (1000 <= lot < 10000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0000{block}____0{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif block < 10 and (10000 <= lot < 100000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0000{block}____{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10 <= block < 100) and lot < 10:
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}000{block}____0000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10 <= block < 100) and (10 <= lot < 100):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}000{block}____000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10 <= block < 100) and (100 <= lot < 1000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}000{block}____00{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10 <= block < 100) and (1000 <= lot < 10000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}000{block}____0{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10 <= block < 100) and (10000 <= lot < 100000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}000{block}____{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (100 <= block < 1000) and lot < 10:
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}00{block}____0000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (100 <= block < 1000) and (10 <= lot < 100):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}00{block}____000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (100 <= block < 1000) and (100 <= lot < 1000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}00{block}____00{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (100 <= block < 1000) and (1000 <= lot < 10000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}00{block}____0{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (100 <= block < 1000) and (10000 <= lot < 100000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}00{block}____{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (1000 <= block < 10000) and lot < 10:
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0{block}____0000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (1000 <= block < 10000) and (10 <= lot < 100):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0{block}____000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (1000 <= block < 10000) and (100 <= lot < 1000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0{block}____00{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (1000 <= block < 10000) and (1000 <= lot < 10000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0{block}____0{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (1000 <= block < 10000) and (10000 <= lot < 100000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}0{block}____{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10000 <= block < 100000) and lot < 10:
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}{block}____0000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10000 <= block < 100000) and (10 <= lot < 100):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}{block}____000{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10000 <= block < 100000) and (100 <= lot < 1000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}{block}____00{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10000 <= block < 100000) and (1000 <= lot < 10000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}{block}____0{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif (10000 <= block < 100000) and (10000 <= lot < 100000):
    url = 'https://tax1.co.monmouth.nj.us/cgi-bin/m4?district={county}{town_city}&I02={county}{town_city}{block}____{lot}_________M'.format(county, town_city, county, town_city, block, lot)
elif re.search('\d\D\d', block) and lot < 10:
    
elif re.search('\d\D\d', block) and (10 < lot <= 100):
    
elif re.search('\d\D\d', block) and (100 < lot <= 1000):
    
elif re.search('\d\D\d', block) and (1000 < lot <= 10000):
    
elif re.search('\d\D\d', block) and (10000 < lot <= 100000):
    
elif re.search('\d\D\d\d', block) and lot < 10:
    
elif re.search('\d\D\d\d', block) and (10 < lot <= 100):
    
elif re.search('\d\D\d\d', block) and (100 < lot <= 1000):
    
elif re.search('\d\D\d\d', block) and (1000 < lot <= 10000):
    
elif re.search('\d\D\d\d', block) and (10000 < lot <= 100000):
    
elif re.search('\d\d\D\d', block) and lot < 10:
    
elif re.search('\d\d\D\d', block) and (10 < lot <= 100):
    
elif re.search('\d\d\D\d', block) and (100 < lot <= 1000):
    
elif re.search('\d\d\D\d', block) and (1000 < lot <= 10000):
    
elif re.search('\d\d\D\d', block) and (10000 < lot <= 100000):
    
elif re.search('\d\d\D\d\d', block) and lot < 10:
    
elif re.search('\d\d\D\d\d', block) and (10 < lot <= 100):
    
elif re.search('\d\d\D\d\d', block) and (100 < lot <= 1000):
    
elif re.search('\d\d\D\d\d', block) and (1000 < lot <= 10000):
    
elif re.search('\d\d\D\d\d', block) and (10000 < lot <= 100000):
    
elif re.search('\d\d\d\D\d', block) and lot < 10:
    
elif re.search('\d\d\d\D\d', block) and (10 < lot <= 100):
    
elif re.search('\d\d\d\D\d', block) and (100 < lot <= 1000):
    
elif re.search('\d\d\d\D\d', block) and (1000 < lot <= 10000):
    
elif re.search('\d\d\d\D\d', block) and (10000 < lot <= 100000):
    
elif re.search('\d\d\d\D\d\d', block) and lot < 10:
    
elif re.search('\d\d\d\D\d\d', block) and (10 < lot <= 100):
    
elif re.search('\d\d\d\D\d\d', block) and (100 < lot <= 1000):
    
elif re.search('\d\d\d\D\d\d', block) and (1000 < lot <= 10000):
    
elif re.search('\d\d\d\D\d\d', block) and (10000 < lot <= 100000):
    
elif re.search('\d\d\d\d\D\d', block) and lot < 10:
    
elif re.search('\d\d\d\d\D\d', block) and (10 < lot <= 100):
    
elif re.search('\d\d\d\d\D\d', block) and (100 < lot <= 1000):
    
elif re.search('\d\d\d\d\D\d', block) and (1000 < lot <= 10000):
    
elif re.search('\d\d\d\d\D\d', block) and (10000 < lot <= 100000):
    
elif re.search('\d\d\d\d\D\d\d', block) and lot < 10:
    
elif re.search('\d\d\d\d\D\d\d', block) and (10 < lot <= 100):
    
elif re.search('\d\d\d\d\D\d\d', block) and (100 < lot <= 1000):
    
elif re.search('\d\d\d\d\D\d\d', block) and (1000 < lot <= 10000):
    
elif re.search('\d\d\d\d\D\d\d', block) and (10000 < lot <= 100000):
    
elif re.search('\d\d\d\d\d\D\d', block) and lot < 10:
    
elif re.search('\d\d\d\d\d\D\d', block) and (10 < lot <= 100):
    
elif re.search('\d\d\d\d\d\D\d', block) and (100 < lot <= 1000):
    
elif re.search('\d\d\d\d\d\D\d', block) and (1000 < lot <= 10000):
    
elif re.search('\d\d\d\d\d\D\d', block) and (10000 < lot <= 100000):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and lot < 10:
    
elif re.search('\d\d\d\d\d\D\d\d', block) and (10 < lot <= 100):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and (100 < lot <= 1000):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and (1000 < lot <= 10000):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and (10000 < lot <= 100000):
    
elif re.search('\d\D\d', block) and re.search('\d\D\d', lot):
    
elif re.search('\d\D\d', block) and re.search('\d\d\D\d', lot):
    
elif re.search('\d\D\d', block) and re.search('\d\d\d\D\d', lot):
    
elif re.search('\d\D\d', block) and re.search('\d\d\d\d\D\d', lot):
    
elif re.search('\d\D\d', block) and re.search('\d\d\d\d\d\D\d', lot):
    
elif re.search('\d\D\d', block) and re.search('\d\D\d\d', lot):
    
elif re.search('\d\D\d', block) and re.search('\d\d\D\d\d', lot):
    
elif re.search('\d\D\d', block) and re.search('\d\d\d\D\d\d', lot):
    
elif re.search('\d\D\d', block) and re.search('\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\D\d', block) and re.search('\d\d\d\d\d\D\d\d', lot):

elif re.search('\d\D\d\d', block) and re.search('\d\D\d', lot):
    
elif re.search('\d\D\d\d', block) and re.search('\d\d\D\d', lot):
    
elif re.search('\d\D\d\d', block) and re.search('\d\d\d\D\d', lot):
    
elif re.search('\d\D\d\d', block) and re.search('\d\d\d\d\D\d', lot):
    
elif re.search('\d\D\d\d', block) and re.search('\d\d\d\d\d\D\d', lot):
    
elif re.search('\d\D\d\d', block)and re.search('\d\D\d\d', lot):
    
elif re.search('\d\D\d\d', block) and re.search('\d\d\D\d\d', lot):
    
elif re.search('\d\D\d\d', block) and re.search('\d\d\d\D\d\d', lot):
    
elif re.search('\d\D\d\d', block) and re.search('\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\D\d\d', block) and re.search('\d\d\d\d\d\D\d\d', lot):

elif re.search('\d\d\D\d', block) and re.search('\d\D\d', lot):
    
elif re.search('\d\d\D\d', block) and re.search('\d\d\D\d', lot):
    
elif re.search('\d\d\D\d', block) and re.search('\d\d\d\D\d', lot):
    
elif re.search('\d\d\D\d', block) and re.search('\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\D\d', block) and re.search('\d\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\D\d', block) and re.search('\d\D\d\d', lot):
    
elif re.search('\d\d\D\d', block) and re.search('\d\d\D\d\d', lot):
    
elif re.search('\d\d\D\d', block) and re.search('\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\D\d', block) and re.search('\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\D\d', block) and re.search('\d\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\D\d\d', block) and re.search('\d\D\d', lot):
    
elif re.search('\d\d\D\d\d', block) and re.search('\d\d\D\d', lot):
    
elif re.search('\d\d\D\d\d', block) and re.search('\d\d\d\D\d', lot):
    
elif re.search('\d\d\D\d\d', block) and re.search('\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\D\d\d', block) and re.search('\d\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\D\d\d', block) and re.search('\d\D\d\d', lot):
    
elif re.search('\d\d\D\d\d', block) and re.search('\d\d\D\d\d', lot):
    
elif re.search('\d\d\D\d\d', block) and re.search('\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\D\d\d', block) and re.search('\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\D\d\d', block) and re.search('\d\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\D\d', block) and re.search('\d\D\d', lot):
    
elif re.search('\d\d\d\D\d', block) and re.search('\d\d\D\d', lot):
    
elif re.search('\d\d\d\D\d', block) and re.search('\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\D\d', block) and re.search('\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\D\d', block) and re.search('\d\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\D\d', block) and re.search('\d\D\d\d', lot):
    
elif re.search('\d\d\d\D\d', block) and re.search('\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\D\d', block) and re.search('\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\D\d', block) and re.search('\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\D\d', block) and re.search('\d\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\D\d\d', block) and re.search('\d\D\d', lot):
    
elif re.search('\d\d\d\D\d\d', block) and re.search('\d\d\D\d', lot):
    
elif re.search('\d\d\d\D\d\d', block) and re.search('\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\D\d\d', block) and re.search('\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\D\d\d', block) and re.search('\d\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\D\d\d', block) and re.search('\d\D\d\d', lot):
    
elif re.search('\d\d\d\D\d\d', block) and re.search('\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\D\d\d', block) and re.search('\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\D\d\d', block) and re.search('\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\D\d\d', block) and re.search('\d\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\D\d', block) and re.search('\d\D\d', lot):
    
elif re.search('\d\d\d\d\D\d', block) and re.search('\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\D\d', block) and re.search('\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\D\d', block) and re.search('\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\D\d', block) and re.search('\d\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\D\d', block) and re.search('\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\D\d', block) and re.search('\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\D\d', block) and re.search('\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\D\d', block) and re.search('\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\D\d', block) and re.search('\d\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\D\d\d', block) and re.search('\d\D\d', lot):
    
elif re.search('\d\d\d\d\D\d\d', block) and re.search('\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\D\d\d', block) and re.search('\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\D\d\d', block) and re.search('\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\D\d\d', block) and re.search('\d\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\D\d\d', block) and re.search('\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\D\d\d', block) and re.search('\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\D\d\d', block) and re.search('\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\D\d\d', block) and re.search('\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\D\d\d', block) and re.search('\d\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\d\D\d', block) and re.search('\d\D\d', lot):
    
elif re.search('\d\d\d\d\d\D\d', block) and re.search('\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\d\D\d', block) and re.search('\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\d\D\d', block) and re.search('\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\d\D\d', block) and re.search('\d\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\d\D\d', block) and re.search('\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\d\D\d', block) and re.search('\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\d\D\d', block) and re.search('\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\d\D\d', block) and re.search('\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\d\D\d', block) and re.search('\d\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and re.search('\d\D\d', lot):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and re.search('\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and re.search('\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and re.search('\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and re.search('\d\d\d\d\d\D\d', lot):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and re.search('\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and re.search('\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and re.search('\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and re.search('\d\d\d\d\D\d\d', lot):
    
elif re.search('\d\d\d\d\d\D\d\d', block) and re.search('\d\d\d\d\d\D\d\d', lot):
# Out:
# County: Hudson
# Township/Municipality/City: Hoboken
# Block: 1
# Lot: 15
# 5

# %% [markdown]
# ## Finalized Code

# %%
## Retrieve necessary libraries
import BS4 as bs
import pandas as pd

## url retrieval

## create the dataframe, including naming the columns
## NOTE: The order you input the names will be the order of the column names
assm_df = pd.DataFrame(columns=['block','lot','prop_loc','owner','sq_ft','district','street', 'year_built','qual','class_','city_state','style','prior_block','acct_num','addl_lots','epl_code','prior_lot','mtg_act','land_desc','statute','prior_qual','bank_code','bldg_desc','initial','updated','tax_codes','class4cd','desc','zone','map_page','acreage','taxes','sale_date','book', 'price','NU'])

## read the HTML data into the 
assm_data = pd.read_html(url, flavor='bs4')

## use indexes to lock in the data
block = assm_data[0][1][0]
lot = assm_data[0][1][1]
qual = assm_data[0][1][2]
prior_block = assm_data[0][1][4]
prior_lot = assm_data[0][1][5]
prior_qual = assm_data[0][1][6]
updated = assm_data[0][1][7]
zone = assm_data[0][1][8]
sale_date = assm_data[0][1][10]
prop_loc = assm_data[0][3][0]
district = assm_data[0][3][1]
class_ = assm_data[0][3][2]
acct_num = assm_data[0][3][4]
mtg_acct = assm_data[0][3][5]
bank_code = assm_data[0][3][6]
tax_codes = assm_data[0][3][7]
map_page = assm_data[0][3][8]
book = assm_data[0][3][10]
owner = assm_data[0][5][0]
street = assm_data[0][5][1]
city_state = assm_data[0][5][2]
addl_lots = assm_data[0][5][4]
land_desc = assm_data[0][5][5]
bldg_desc = assm_data[0][5][6]
class4cd = assm_data[0][5][7]
acreage = assm_data[0][5][8]
price = assm_data[0][5][10][0]
sq_ft = assm_data[0][7][0]
year_built = assm_data[0][7][1]
style = assm_data[0][7][2]
epl_code = assm_data[0][7][4]
statute = assm_data[0][7][5]
initial = assm_data[0][7][6]
desc = assm_data[0][7][7]
taxes = assm_data[0][7][8]
NU = assm_data[0][5][10][-1]

## add them to the pandas dataframe
## this does not have the same order so keep in mind if manually checking
assm_df = assm_df.append({'block': block, 'lot': lot, 'prop_loc': prop_loc,'owner': owner,'sq_ft': sq_ft, 'district': district,'street': street, 'year_built': year_built, 'qual': qual,'class_': class_,'city_state': city_state,'style': style, 'prior_block': prior_block,'acct_num': acct_num, 'addl_lots': addl_lots,'epl_code': epl_code, 'prior_lot': prior_lot,'mtg_acct': mtg_acct,'land_desc': land_desc,'statute': statute, 'prior_qual': prior_qual,'bank_code': bank_code,'bldg_desc': bldg_desc,'initial': initial, 'updated': updated,'tax_codes': tax_codes,'class4cd': class4cd,'desc': desc, 'zone': zone,'map_page': map_page,'acreage': acreage,'taxes': taxes, 'sale_date': sale_date,'book': book, 'price': price,'NU': NU},ignore_index=True)

## write the data into the file
with pd.ExcelWriter(r'C:\Users\jeffg\downloads\test.xlsx', mode='a', engine='openpyxl', if_sheet_exists = 'replace') as writer:
    assm_df.to_excel(writer,sheet_name='test_2')
    writer.save()

# %% [markdown]
# # Projections
#
# We want legal projections, which conceptually should be able to crafted through a regression - which type is yet to be seen

# %% [markdown]
# [Data Science in Property Tax Appeals: Article](https://www.rethinksolutions.com/post/determining-real-estate-appeal-opportunities-using-technology)

# %%
# install dash
# !pip install dash

# %%
## load libs
import pandas as pd
import NumPy as np
import sklearn
import pandas as pd
import plotly.graph_objects as go
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px
